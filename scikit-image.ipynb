# %%
import skimage

# %%
from skimage import data
camera = data.camera()

# %%
type(camera)
# Out:
# numpy.ndarray

# %%
camera.shape
# Out:
# (512, 512)

# %%
import os
fn = os.path.join(skimage.data_dir, 'moon.png')

# %%
print(fn)
# Out:
# /Users/bapvn/virtualenvs/myvenv/lib/python3.6/site-packages/skimage/data/moon.png

# %%
from skimage import io

# %%
file = io.imread(fn)

# %%
print(file)
# Out:
# [[116 116 122 ...  93  96  96]
#  [116 116 122 ...  93  96  96]
#  [116 116 122 ...  93  96  96]
#  ...
#  [109 109 112 ... 117 116 116]
#  [114 114 113 ... 118 118 118]
#  [114 114 113 ... 118 118 118]]

# %%
io.imshow(file)

# %%
io.imshow(camera)
